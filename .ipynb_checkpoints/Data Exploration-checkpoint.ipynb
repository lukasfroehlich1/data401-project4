# %%
import pandas as pd
import numpy as np
import glob
import csv

# %%
county_files = glob.glob("./election-2012-results/data/*")

# %%
for county in county_files:
    
    with open(county_csvs[0]) as f:
        read = csv.reader(f)

        for line in read:
            print(line)
# Out:
# ['fips', 'county', 'candidate', 'votes']
# ['18001', 'Adams', 'Obama', '3806']
# ['18001', 'Adams', 'Johnson', '262']
# ['18001', 'Adams', 'Romney', '8937']
# ['18001', 'Adams', 'Goode', '2']
# ['18001', 'Adams', 'Knill', '0']
# ['18001', 'Adams', 'Durham', '0']
# ['18003', 'Allen', 'Obama', '60036']
# ['18003', 'Allen', 'Johnson', '2197']
# ['18003', 'Allen', 'Romney', '84613']
# ['18003', 'Allen', 'Goode', '16']
# ['18003', 'Allen', 'Knill', '0']
# ['18003', 'Allen', 'Durham', '0']
# ['18005', 'Bartholomew', 'Obama', '10625']
# ['18005', 'Bartholomew', 'Johnson', '608']
# ['18005', 'Bartholomew', 'Romney', '18083']
# ['18005', 'Bartholomew', 'Goode', '4']
# ['18005', 'Bartholomew', 'Knill', '0']
# ['18005', 'Bartholomew', 'Durham', '0']
# ['18007', 'Benton', 'Obama', '1159']
# ['18007', 'Benton', 'Johnson', '89']
# ['18007', 'Benton', 'Romney', '2329']
# ['18007', 'Benton', 'Goode', '0']
# ['18007', 'Benton', 'Knill', '0']
# ['18007', 'Benton', 'Durham', '0']
# ...
